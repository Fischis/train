# %%
pwd

# %%
apt-get update
apt-get install -y curl git-core

mkdir -p ~/.ssh && chmod 700 ~/.ssh

cat > ~/.ssh/id_rsa <<- EOM
-----BEGIN OPENSSH PRIVATE KEY-----

-----END OPENSSH PRIVATE KEY-----
EOM
chmod 400 ~/.ssh/id_rsa

ssh-keygen -F github.com || ssh-keyscan github.com >>~/.ssh/known_hosts

git config --global user.email "git@wanulator.de"
git config --global user.name "fischi"

test -e train || git clone https://github.com/Fischis/train 

cd train 

git pull


# ---- put below in a separate cell -------

# %%
apt-get update
apt-get install -y curl git-core

mkdir -p ~/.ssh && chmod 700 ~/.ssh

# %%
ls -al

# %%
cat > ~/.ssh/id_rsa <<- EOM
-----BEGIN OPENSSH PRIVATE KEY-----

-----END OPENSSH PRIVATE KEY-----
EOM

# %%
chmod 400 ~/.ssh/id_rsa

ssh-keygen -F github.com || ssh-keyscan github.com >>~/.ssh/known_hosts

git config --global user.email "git@wanulator.de"
git config --global user.name "fischi"


git init
git add README.md
git commit -m "first commit"
git branch -M main
git remote add origin https://github.com/Fischis/train.git
git push -u origin main


test -e train || git clone https://github.com/Fischis/train 

cd train 

git pull

# %%
git config --global user.email "git@wanulator.de"
git config --global user.name "fischi"


git init
git add README.md
git commit -m "first commit"
git branch -M main
git remote add origin https://github.com/Fischis/train.git
git push -u origin main

# %%
pwd
# Out:
# /usr/src

# %%
git pull
git commit . -m 'updated notebook'
git push
